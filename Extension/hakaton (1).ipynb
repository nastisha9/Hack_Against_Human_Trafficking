# %%
import pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

train_data_path = 'train1.csv'  # Replace with your file path
test_data_path = 'test1.csv'    # Replace with your file path
val_data_path = 'test_validation.csv'  # Replace with your file path

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)
val_data = pd.read_csv(val_data_path)

# Parameters for tokenization
max_words = 10000  # Consider only the top 10,000 words in the dataset

# Initialize the tokenizer
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(train_data['job description'])

# Convert the text in each dataset to sequences
train_sequences = tokenizer.texts_to_sequences(train_data['job description'])
test_sequences = tokenizer.texts_to_sequences(test_data['job description'])
val_sequences = tokenizer.texts_to_sequences(val_data['job description'])

max_len = 100  # Cut off after 100 words

# Extract labels before overwriting the train and validation data
train_labels = np.asarray(train_data['label'].astype('float32'))
val_labels = np.asarray(val_data['label'].astype('float32'))

# Pad sequences
padded_train_data = pad_sequences(train_sequences, maxlen=max_len)
padded_test_data = pad_sequences(test_sequences, maxlen=max_len)
padded_val_data = pad_sequences(val_sequences, maxlen=max_len)

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=32, input_length=max_len)) # Embedding layer
model.add(LSTM(32))  # LSTM layer with 32 units
model.add(Dense(1, activation='sigmoid'))  # Output layer with sigmoid activation for binary classification

model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(padded_train_data, train_labels, epochs=100, batch_size=64, validation_data=(padded_val_data, val_labels))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 4s 320ms/step - loss: 0.6889 - accuracy: 0.5660 - val_loss: 0.6975 - val_accuracy: 0.2381
# Epoch 2/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.6757 - accuracy: 0.5723 - val_loss: 0.6994 - val_accuracy: 0.2381
# Epoch 3/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.6579 - accuracy: 0.5723 - val_loss: 0.6918 - val_accuracy: 0.2857
# Epoch 4/100
# 3/3 [==============================] - 0s 78ms/step - loss: 0.6282 - accuracy: 0.5975 - val_loss: 0.6891 - val_accuracy: 0.2857
# Epoch 5/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.5770 - accuracy: 0.6038 - val_loss: 0.6569 - val_accuracy: 0.4048
# Epoch 6/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.4871 - accuracy: 0.7987 - val_loss: 0.5298 - val_accuracy: 0.7857
# Epoch 7/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.3507 - accuracy: 0.9560 - val_loss: 0.3810 - val_accuracy: 1.0000
# Epoch 8/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.2270 - accuracy: 0.9937 - val_loss: 0.3283 - val_accuracy: 0.9762
# Epoch 9/100
# 3/3 [==============================] - 0s 61ms/step - loss: 0.1659 - accuracy: 1.0000 - val_loss: 0.2992 - val_accuracy: 0.9524
# Epoch 10/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.1579 - accuracy: 0.9811 - val_loss: 0.2609 - val_accuracy: 0.9762
# Epoch 11/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.1550 - accuracy: 0.9811 - val_loss: 0.2342 - val_accuracy: 0.9762
# Epoch 12/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.1298 - accuracy: 0.9937 - val_loss: 0.2278 - val_accuracy: 0.9762
# Epoch 13/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.1144 - accuracy: 0.9937 - val_loss: 0.1955 - val_accuracy: 0.9762
# Epoch 14/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0988 - accuracy: 0.9937 - val_loss: 0.1789 - val_accuracy: 0.9762
# Epoch 15/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0863 - accuracy: 1.0000 - val_loss: 0.1662 - val_accuracy: 0.9762
# Epoch 16/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0750 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9524
# Epoch 17/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0654 - accuracy: 1.0000 - val_loss: 0.1483 - val_accuracy: 0.9762
# Epoch 18/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0556 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9524
# Epoch 19/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0728 - accuracy: 0.9874 - val_loss: 0.1340 - val_accuracy: 0.9762
# Epoch 20/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 0.9762
# Epoch 21/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0457 - accuracy: 1.0000 - val_loss: 0.1625 - val_accuracy: 0.9762
# Epoch 22/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9762
# Epoch 23/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.1267 - val_accuracy: 0.9524
# Epoch 24/100
# 3/3 [==============================] - 0s 84ms/step - loss: 0.0335 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 0.9524
# Epoch 25/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.1364 - val_accuracy: 0.9524
# Epoch 26/100
# 3/3 [==============================] - 0s 85ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.1436 - val_accuracy: 0.9762
# Epoch 27/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 0.9524
# Epoch 28/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9524
# Epoch 29/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 0.9524
# Epoch 30/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9286
# Epoch 31/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.1764 - val_accuracy: 0.9286
# Epoch 32/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.1296 - val_accuracy: 0.9762
# Epoch 33/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0591 - accuracy: 0.9874 - val_loss: 0.5850 - val_accuracy: 0.8333
# Epoch 34/100
# 3/3 [==============================] - 0s 63ms/step - loss: 0.1954 - accuracy: 0.9245 - val_loss: 0.1408 - val_accuracy: 0.9762
# Epoch 35/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.1357 - val_accuracy: 0.9762
# Epoch 36/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.1314 - val_accuracy: 0.9524
# Epoch 37/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.9524
# Epoch 38/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 0.9524
# Epoch 39/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9762
# Epoch 40/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 0.9524
# Epoch 41/100
# 3/3 [==============================] - 0s 89ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9762
# Epoch 42/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9762
# Epoch 43/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 0.9762
# Epoch 44/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0978 - val_accuracy: 0.9762
# Epoch 45/100
# 3/3 [==============================] - 0s 111ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9762
# Epoch 46/100
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.1011 - val_accuracy: 0.9762
# Epoch 47/100
# 3/3 [==============================] - 0s 137ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.9524
# Epoch 48/100
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 0.9762
# Epoch 49/100
# 3/3 [==============================] - 0s 113ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.1129 - val_accuracy: 0.9524
# Epoch 50/100
# 3/3 [==============================] - 0s 105ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.1320 - val_accuracy: 0.9524
# Epoch 51/100
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 0.9524
# Epoch 52/100
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.1721 - val_accuracy: 0.9524
# Epoch 53/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1405 - val_accuracy: 0.9524
# Epoch 54/100
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.1818 - val_accuracy: 0.9524
# Epoch 55/100
# 3/3 [==============================] - 0s 116ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1543 - val_accuracy: 0.9524
# Epoch 56/100
# 3/3 [==============================] - 0s 119ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.7328 - val_accuracy: 0.8095
# Epoch 57/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.1227 - accuracy: 0.9497 - val_loss: 0.1811 - val_accuracy: 0.9524
# Epoch 58/100
# 3/3 [==============================] - 0s 122ms/step - loss: 0.0425 - accuracy: 0.9937 - val_loss: 0.1618 - val_accuracy: 0.9762
# Epoch 59/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0409 - accuracy: 0.9937 - val_loss: 0.1561 - val_accuracy: 0.9762
# Epoch 60/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9762
# Epoch 61/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9762
# Epoch 62/100
# 3/3 [==============================] - 0s 86ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9762
# Epoch 63/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9762
# Epoch 64/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.9762
# Epoch 65/100
# 3/3 [==============================] - 0s 74ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.9762
# Epoch 66/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9762
# Epoch 67/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9762
# Epoch 68/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9762
# Epoch 69/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9762
# Epoch 70/100
# 3/3 [==============================] - 0s 79ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9762
# Epoch 71/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9762
# Epoch 72/100
# 3/3 [==============================] - 0s 80ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1461 - val_accuracy: 0.9762
# Epoch 73/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9762
# Epoch 74/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9762
# Epoch 75/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9762
# Epoch 76/100
# 3/3 [==============================] - 0s 72ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1460 - val_accuracy: 0.9762
# Epoch 77/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9762
# Epoch 78/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9524
# Epoch 79/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2039 - val_accuracy: 0.9524
# Epoch 80/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2043 - val_accuracy: 0.9524
# Epoch 81/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.1877 - val_accuracy: 0.9524
# Epoch 82/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1857 - val_accuracy: 0.9048
# Epoch 83/100
# 3/3 [==============================] - 0s 71ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2243 - val_accuracy: 0.9286
# Epoch 84/100
# 3/3 [==============================] - 0s 65ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9048
# Epoch 85/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 0.9048
# Epoch 86/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4053 - val_accuracy: 0.9048
# Epoch 87/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4294 - val_accuracy: 0.9048
# Epoch 88/100
# 3/3 [==============================] - 0s 62ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3483 - val_accuracy: 0.9286
# Epoch 89/100
# 3/3 [==============================] - 0s 70ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3060 - val_accuracy: 0.9524
# Epoch 90/100
# 3/3 [==============================] - 0s 64ms/step - loss: 0.0707 - accuracy: 0.9748 - val_loss: 0.1364 - val_accuracy: 0.9524
# Epoch 91/100
# 3/3 [==============================] - 0s 67ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.9524
# Epoch 92/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9524
# Epoch 93/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9524
# Epoch 94/100
# 3/3 [==============================] - 0s 76ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1366 - val_accuracy: 0.9524
# Epoch 95/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9524
# Epoch 96/100
# 3/3 [==============================] - 0s 73ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1370 - val_accuracy: 0.9524
# Epoch 97/100
# 3/3 [==============================] - 0s 69ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1371 - val_accuracy: 0.9524
# Epoch 98/100
# 3/3 [==============================] - 0s 75ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1372 - val_accuracy: 0.9524
# Epoch 99/100
# 3/3 [==============================] - 0s 68ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1375 - val_accuracy: 0.9524
# Epoch 100/100
# 3/3 [==============================] - 0s 66ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1379 - val_accuracy: 0.9524

# %%
# Load test data
test_data_path = 'test1.csv'  # Replace with your file path
test_data = pd.read_csv(test_data_path)

# Tokenize and pad the test data
test_sequences = tokenizer.texts_to_sequences(test_data['job description'])
padded_test_data = pad_sequences(test_sequences, maxlen=max_len)

predicted_labels = model.predict(padded_test_data)
predicted_labels = (predicted_labels > 0.5).astype('int32')  # Convert probabilities to 0 or 1

val_data_path = 'test_validation.csv'  # Replace with your file path
validation_data = pd.read_csv(val_data_path)
actual_labels = np.asarray(validation_data['label'].astype('int32'))

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Calculate metrics
accuracy = accuracy_score(val_labels, predicted_labels)
precision = precision_score(val_labels, predicted_labels)
recall = recall_score(val_labels, predicted_labels)
f1 = f1_score(val_labels, predicted_labels)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# 2/2 [==============================] - 2s 30ms/step
# Accuracy: 0.9523809523809523
# Precision: 0.9411764705882353
# Recall: 1.0
# F1 Score: 0.9696969696969697

# %%
def predict_job_offer(model, tokenizer, job_offer_text, max_len=100):
    # Tokenize and pad the job offer
    sequence = tokenizer.texts_to_sequences([job_offer_text])
    padded_sequence = pad_sequences(sequence, maxlen=max_len)

    # Predict
    prediction = model.predict(padded_sequence)
    predicted_label = (prediction > 0.5).astype('int32')

    # Interpret the prediction
    if predicted_label[0][0] == 1:
        return "Dangerous/Scam"
    else:
        return "Safe"

# job offer from 999
new_job_offer = "Work in Poland at the poultry meat plant *We employ unqualified persons with biometric passport *Primim women, barabti and pairs *The employment is made legally by a 3-month employment contract *It is possible to extend ducoments up to 3 years *Salary is stable every month + weekly advances *The accommodation is free *It is possible to live only one pair in the room *Hrana 3 times a day for free *Work consists of wrapping and cutting meat *Salary from 20-23 zlotys/hour netto for cutting and slicing products *Salary: 0,20zlot/kg for butchers with environmental experience 1000zlot/monthly *Average monthly salary from 1300-1500€ *Temperature at work +10 *It is worked 10-12 hours a day for months until Saturday (saturday at the wish) *To leave only biometric or European passport we will pay and the road. *Moldova-Poland transport paid by the employer *Contract directly to the employer, you pay nothing for employment you pay nothing for departure Zero expenses - 100% guarantee% The thing is certain because it is legal by contract of employment and you do not have to pay anything . For more details call this phone number"

result = predict_job_offer(model, tokenizer, new_job_offer, max_len)
print(f"The job offer is predicted to be: {result}")
# Out:
# 1/1 [==============================] - 0s 202ms/step
# The job offer is predicted to be: Dangerous/Scam
